# %%
import LinearRegressionSkeleton

# %%
asd=LinearRegressionSkeleton.LinearRegression()

# %%
asd.fit(asd.X,asd.y)
# Out:
# 5.809166666666666
# 3.5664605404142944
# 2.267586223792104
# 1.5119126138879924
# 1.0690035714555222
# 0.8063106764303264
# 0.6475858994028542
# 0.5489627461872929
# 0.4851993752529476
# 0.44176634574828655

# %%
asd.predict(asd.X)
